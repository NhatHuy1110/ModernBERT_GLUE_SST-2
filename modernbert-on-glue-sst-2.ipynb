# %%
# !pip uninstall -y flash-attn flash_attn 2>/dev/null
# !pip install -q "transformers>=4.46.0" datasets evaluate accelerate

# %%
import torch, platform
print("Torch:", torch.__version__, "| CUDA available:", torch.cuda.is_available())
# !nvidia-smi -L || true
# Out:
# Torch: 2.6.0+cu124 | CUDA available: True
# GPU 0: Tesla P100-PCIE-16GB (UUID: GPU-24d2e2d8-f9b2-6dab-9cec-63008accf7f1)

# %% [markdown]
# # Import

# %%
import os
os.environ["DISABLE_FLASH_ATTN"] = "1"

# %%
import math
import random
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModel, AutoModelForSequenceClassification
from transformers.optimization import get_linear_schedule_with_warmup
import evaluate
from tqdm import tqdm
# Out:
# 2025-08-21 07:55:56.568212: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755762956.590748     233 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755762956.597572     233 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
# Seed
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

set_seed(42)

# %% [markdown]
# # Tokenizer

# %%
MODEL_ID = "answerdotai/ModernBERT-base"
tokenizer = AutoTokenizer.from_pretrained(MODEL_ID, use_fast=True)
MAX_LEN = 128

# %% [markdown]
# # Dataset

# %%
raw_ds = load_dataset("glue", "sst2")

# %%
def tok_fn(batch):
    return tokenizer(
        batch["sentence"],
        truncation=True,
        padding="max_length",
        max_length=MAX_LEN
    )

# %%
train_ds = raw_ds["train"].map(tok_fn, batched=True)
val_ds   = raw_ds["validation"].map(tok_fn, batched=True)
# Out:
# Map:   0%|          | 0/67349 [00:00<?, ? examples/s]

# %%
# HuggingFace datasets -> torch
train_ds = train_ds.rename_column("label", "labels")
val_ds   = val_ds.rename_column("label", "labels")

train_ds.set_format(type="torch", columns=["input_ids", "attention_mask", "labels"])
val_ds.set_format(type="torch", columns=["input_ids", "attention_mask", "labels"])

# %%
len(train_ds)
# Out:
# 67349

# %%
len(val_ds)
# Out:
# 872

# %% [markdown]
# # DataLoader

# %%
BATCH_SIZE = 32

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, pin_memory=True)
val_loader   = DataLoader(val_ds,   batch_size=BATCH_SIZE*2, shuffle=False, pin_memory=True)

print("Batches:", len(train_loader), len(val_loader))
# Out:
# Batches: 2105 14

# %% [markdown]
# # ModernBERT Classifier (không có flash-attn)

# %%
class ModernBERTClassifier(nn.Module):
    def __init__(self, model_name: str, num_labels: int = 2, dropout: float = 0.1):
        super().__init__()
        
        self.backbone = AutoModel.from_pretrained(model_name, torch_dtype=torch.float32)
        hidden = self.backbone.config.hidden_size
        self.dropout = nn.Dropout(dropout)
        self.classifier = nn.Linear(hidden, num_labels)

    def forward(self, input_ids, attention_mask, labels=None):
        out = self.backbone(input_ids=input_ids, attention_mask=attention_mask)
        
        cls = out.last_hidden_state[:, 0]         
        cls = self.dropout(cls)
        logits = self.classifier(cls)              

        loss = None
        if labels is not None:
            loss = nn.CrossEntropyLoss()(logits, labels)
        return logits, loss

# %%
model = ModernBERTClassifier(MODEL_ID, num_labels=2).to(device)

# %% [markdown]
# # Optimizer, Scheduler, AWP

# %%
LR = 2e-5
EPOCHS = 20
WEIGHT_DECAY = 0.01
WARMUP_RATIO = 0.06      
GRAD_ACCUM_STEPS = 1     
MAX_GRAD_NORM = 1.0

# %%
optimizer = torch.optim.AdamW(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)

# %%
total_steps = math.ceil(len(train_loader) / GRAD_ACCUM_STEPS) * EPOCHS
warmup_steps = int(total_steps * WARMUP_RATIO)

# %%
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=warmup_steps, num_training_steps=total_steps)

# %%
# scaler = torch.cuda.amp.GradScaler(enabled=torch.cuda.is_available())

scaler = torch.amp.GradScaler("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Eval

# %%
metric_acc = evaluate.load("accuracy")
metric_f1  = evaluate.load("f1")

# %%
@torch.no_grad()
def evaluate_epoch(model, loader):
    model.eval()
    total_loss = 0.0
    preds_all, labels_all = [], []

    for batch in loader:
        input_ids = batch["input_ids"].to(device, non_blocking=True)
        attention_mask = batch["attention_mask"].to(device, non_blocking=True)
        labels = batch["labels"].to(device, non_blocking=True)

        logits, loss = model(input_ids, attention_mask, labels)
        total_loss += loss.item()

        preds = torch.argmax(logits, dim=-1)
        preds_all.extend(preds.cpu().tolist())
        labels_all.extend(labels.cpu().tolist())

    avg_loss = total_loss / len(loader)
    acc = metric_acc.compute(predictions=preds_all, references=labels_all)["accuracy"]
    f1  = metric_f1.compute(predictions=preds_all, references=labels_all, average="binary")["f1"]
    return {"val_loss": avg_loss, "val_acc": acc, "val_f1": f1}

# %% [markdown]
# # Train thôi

# %%
best_val_acc = 0.0
history = {"train_loss": [], "val_loss": [], "val_acc": [], "val_f1": []}

# %%
torch._inductor.config.cpp_wrapper = False
torch._inductor.config.triton.cudagraphs = False

# %%
import torch._dynamo
torch._dynamo.config.suppress_errors = True

# %%
for epoch in range(1, EPOCHS + 1):
    model.train()
    running = 0.0
    optimizer.zero_grad(set_to_none=True)

    pbar = tqdm(enumerate(train_loader, start=1), total=len(train_loader), desc=f"Epoch {epoch}/{EPOCHS}")
    for step, batch in pbar:
        input_ids = batch["input_ids"].to(device, non_blocking=True)
        attention_mask = batch["attention_mask"].to(device, non_blocking=True)
        labels = batch["labels"].to(device, non_blocking=True)

        with torch.amp.autocast("cuda"):
            logits, loss = model(input_ids, attention_mask, labels)
            loss = loss / GRAD_ACCUM_STEPS

        scaler.scale(loss).backward()

        if step % GRAD_ACCUM_STEPS == 0:
            # gradient clipping
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), MAX_GRAD_NORM)

            scaler.step(optimizer)
            scaler.update()
            optimizer.zero_grad(set_to_none=True)
            scheduler.step()

        running += loss.item() * GRAD_ACCUM_STEPS
        if step % 50 == 0:
            pbar.set_postfix(train_loss=f"{running/step:.4f}")

    train_loss = running / len(train_loader)
    val_metrics = evaluate_epoch(model, val_loader)

    history["train_loss"].append(train_loss)
    history["val_loss"].append(val_metrics["val_loss"])
    history["val_acc"].append(val_metrics["val_acc"])
    history["val_f1"].append(val_metrics["val_f1"])

    print(f">>> E{epoch:02d} | train_loss={train_loss:.4f} | "
          f"val_loss={val_metrics['val_loss']:.4f} | "
          f"val_acc={val_metrics['val_acc']:.4f} | val_f1={val_metrics['val_f1']:.4f}")

    # Lưu best checkpoint theo accuracy
    if val_metrics["val_acc"] > best_val_acc:
        best_val_acc = val_metrics["val_acc"]
        save_path = "/kaggle/working/modernbert_sst2_best.pt" if "KAGGLE_URL_BASE" in os.environ else "/content/modernbert_sst2_best.pt"
        torch.save({"model_state_dict": model.state_dict(),
                    "model_name": MODEL_ID,
                    "tokenizer": tokenizer.name_or_path,
                    "val_acc": best_val_acc},
                   save_path)
        print(f"Saved best model to: {save_path} (acc={best_val_acc:.4f})")
# Out:
# Epoch 1/20:   0%|          | 0/2105 [00:00<?, ?it/s]W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233] WON'T CONVERT compiled_embeddings /usr/local/lib/python3.11/dist-packages/transformers/models/modernbert/modeling_modernbert.py line 204
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233] due to:
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233] Traceback (most recent call last):
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 1164, in __call__
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     result = self._inner_convert(
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]              ^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 547, in __call__
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     return _compile(
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 986, in _compile
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 715, in compile_inner
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     return _compile_inner(code, one_graph, hooks, transform)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_utils_internal.py", line 95, in wrapper_function
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     return function(*args, **kwargs)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 750, in _compile_inner
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     out_code = transform_code_object(code, transform)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/bytecode_transformation.py", line 1361, in transform_code_object
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     transformations(instructions, code_options)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 231, in _fn
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     return fn(*args, **kwargs)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 662, in transform
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     tracer.run()
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 2868, in run
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     super().run()
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 1052, in run
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     while self.step():
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]           ^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 962, in step
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     self.dispatch_table[inst.opcode](self, inst)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 3048, in RETURN_VALUE
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     self._return(inst)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 3033, in _return
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     self.output.compile_subgraph(
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/output_graph.py", line 1101, in compile_subgraph
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     self.compile_and_call_fx_graph(
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/output_graph.py", line 1382, in compile_and_call_fx_graph
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     compiled_fn = self.call_user_compiler(gm)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/output_graph.py", line 1432, in call_user_compiler
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     return self._call_user_compiler(gm)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/output_graph.py", line 1483, in _call_user_compiler
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     raise BackendCompilerFailed(self.compiler_fn, e).with_traceback(
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/output_graph.py", line 1462, in _call_user_compiler
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/repro/after_dynamo.py", line 130, in __call__
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     compiled_gm = compiler_fn(gm, example_inputs)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/__init__.py", line 2340, in __call__
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     return compile_fx(model_, inputs_, config_patches=self.config)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 1863, in compile_fx
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     return aot_autograd(
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/backends/common.py", line 83, in __call__
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 1155, in aot_module_simplified
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     compiled_fn = dispatch_and_compile()
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 1131, in dispatch_and_compile
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     compiled_fn, _ = create_aot_dispatcher_function(
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 580, in create_aot_dispatcher_function
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     return _create_aot_dispatcher_function(
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 830, in _create_aot_dispatcher_function
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     compiled_fn, fw_metadata = compiler_fn(
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]                                ^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/_aot_autograd/jit_compile_runtime_wrappers.py", line 678, in aot_dispatch_autograd
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     compiled_fw_func = aot_config.fw_compiler(fw_module, adjusted_flat_args)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 489, in __call__
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     return self.compiler_fn(gm, example_inputs)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 1741, in fw_compiler_base
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     return inner_compile(
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 569, in compile_fx_inner
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     return wrap_compiler_debug(_compile_fx_inner, compiler_name="inductor")(
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/repro/after_aot.py", line 102, in debug_wrapper
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 685, in _compile_fx_inner
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     mb_compiled_graph = fx_codegen_and_compile(
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]                         ^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 1129, in fx_codegen_and_compile
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     return scheme.codegen_and_compile(gm, example_inputs, inputs_to_check, graph_kwargs)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 1044, in codegen_and_compile
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     compiled_fn = graph.compile_to_module().call
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/graph.py", line 2027, in compile_to_module
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     return self._compile_to_module()
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/graph.py", line 2033, in _compile_to_module
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]                                                              ^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/graph.py", line 1964, in codegen
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     self.scheduler = Scheduler(self.operations)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 1798, in __init__
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     self._init(nodes)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 1816, in _init
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 1816, in <listcomp>
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 1947, in create_scheduler_node
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     return SchedulerNode(self, node)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 893, in __init__
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     self._compute_attrs()
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 907, in _compute_attrs
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     group_fn = self.scheduler.get_backend(device).group_fn
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 3441, in get_backend
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     self.backends[device] = self.create_backend(device)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 3428, in create_backend
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     raise RuntimeError(
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233] RuntimeError: Found Tesla P100-PCIE-16GB which is too old to be supported by the triton GPU compiler, which is used as the backend. Triton only supports devices of CUDA Capability >= 7.0, but your device is of CUDA capability 6.0
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233] Traceback (most recent call last):
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 1164, in __call__
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     result = self._inner_convert(
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]              ^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 547, in __call__
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     return _compile(
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 986, in _compile
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 715, in compile_inner
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     return _compile_inner(code, one_graph, hooks, transform)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_utils_internal.py", line 95, in wrapper_function
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     return function(*args, **kwargs)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 750, in _compile_inner
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     out_code = transform_code_object(code, transform)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/bytecode_transformation.py", line 1361, in transform_code_object
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     transformations(instructions, code_options)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 231, in _fn
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     return fn(*args, **kwargs)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 662, in transform
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     tracer.run()
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 2868, in run
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     super().run()
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 1052, in run
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     while self.step():
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]           ^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 962, in step
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     self.dispatch_table[inst.opcode](self, inst)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 3048, in RETURN_VALUE
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     self._return(inst)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 3033, in _return
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     self.output.compile_subgraph(
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/output_graph.py", line 1101, in compile_subgraph
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     self.compile_and_call_fx_graph(
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/output_graph.py", line 1382, in compile_and_call_fx_graph
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     compiled_fn = self.call_user_compiler(gm)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/output_graph.py", line 1432, in call_user_compiler
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     return self._call_user_compiler(gm)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/output_graph.py", line 1483, in _call_user_compiler
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     raise BackendCompilerFailed(self.compiler_fn, e).with_traceback(
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/output_graph.py", line 1462, in _call_user_compiler
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/repro/after_dynamo.py", line 130, in __call__
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     compiled_gm = compiler_fn(gm, example_inputs)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/__init__.py", line 2340, in __call__
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     return compile_fx(model_, inputs_, config_patches=self.config)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 1863, in compile_fx
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     return aot_autograd(
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/backends/common.py", line 83, in __call__
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 1155, in aot_module_simplified
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     compiled_fn = dispatch_and_compile()
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 1131, in dispatch_and_compile
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     compiled_fn, _ = create_aot_dispatcher_function(
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 580, in create_aot_dispatcher_function
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     return _create_aot_dispatcher_function(
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 830, in _create_aot_dispatcher_function
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     compiled_fn, fw_metadata = compiler_fn(
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]                                ^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/_aot_autograd/jit_compile_runtime_wrappers.py", line 678, in aot_dispatch_autograd
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     compiled_fw_func = aot_config.fw_compiler(fw_module, adjusted_flat_args)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 489, in __call__
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     return self.compiler_fn(gm, example_inputs)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 1741, in fw_compiler_base
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     return inner_compile(
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 569, in compile_fx_inner
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     return wrap_compiler_debug(_compile_fx_inner, compiler_name="inductor")(
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/repro/after_aot.py", line 102, in debug_wrapper
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 685, in _compile_fx_inner
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     mb_compiled_graph = fx_codegen_and_compile(
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]                         ^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 1129, in fx_codegen_and_compile
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     return scheme.codegen_and_compile(gm, example_inputs, inputs_to_check, graph_kwargs)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 1044, in codegen_and_compile
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     compiled_fn = graph.compile_to_module().call
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/graph.py", line 2027, in compile_to_module
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     return self._compile_to_module()
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/graph.py", line 2033, in _compile_to_module
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]                                                              ^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/graph.py", line 1964, in codegen
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     self.scheduler = Scheduler(self.operations)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 1798, in __init__
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     self._init(nodes)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 1816, in _init
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 1816, in <listcomp>
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 1947, in create_scheduler_node
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     return SchedulerNode(self, node)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 893, in __init__
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     self._compute_attrs()
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 907, in _compute_attrs
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     group_fn = self.scheduler.get_backend(device).group_fn
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 3441, in get_backend
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     self.backends[device] = self.create_backend(device)
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 3428, in create_backend
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]     raise RuntimeError(
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233] RuntimeError: Found Tesla P100-PCIE-16GB which is too old to be supported by the triton GPU compiler, which is used as the backend. Triton only supports devices of CUDA Capability >= 7.0, but your device is of CUDA capability 6.0
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W0821 07:59:22.443000 233 torch/_dynamo/convert_frame.py:1233]
# W0821 07:59:23.276000 233 torch/_inductor/utils.py:1137] [1/0] Not enough SMs to use max_autotune_gemm mode
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233] WON'T CONVERT compiled_mlp /usr/local/lib/python3.11/dist-packages/transformers/models/modernbert/modeling_modernbert.py line 523
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233] due to:
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233] Traceback (most recent call last):
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 1164, in __call__
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]     result = self._inner_convert(
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]              ^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 547, in __call__
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]     return _compile(
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 986, in _compile
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 715, in compile_inner
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]     return _compile_inner(code, one_graph, hooks, transform)
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_utils_internal.py", line 95, in wrapper_function
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]     return function(*args, **kwargs)
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 750, in _compile_inner
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]     out_code = transform_code_object(code, transform)
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/bytecode_transformation.py", line 1361, in transform_code_object
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]     transformations(instructions, code_options)
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 231, in _fn
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]     return fn(*args, **kwargs)
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/convert_frame.py", line 662, in transform
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]     tracer.run()
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 2868, in run
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]     super().run()
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 1052, in run
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]     while self.step():
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]           ^^^^^^^^^^^
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 962, in step
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]     self.dispatch_table[inst.opcode](self, inst)
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 3048, in RETURN_VALUE
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]     self._return(inst)
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 3033, in _return
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]     self.output.compile_subgraph(
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/output_graph.py", line 1101, in compile_subgraph
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]     self.compile_and_call_fx_graph(
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/output_graph.py", line 1382, in compile_and_call_fx_graph
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]     compiled_fn = self.call_user_compiler(gm)
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/output_graph.py", line 1432, in call_user_compiler
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]     return self._call_user_compiler(gm)
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/output_graph.py", line 1483, in _call_user_compiler
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]     raise BackendCompilerFailed(self.compiler_fn, e).with_traceback(
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/output_graph.py", line 1462, in _call_user_compiler
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/repro/after_dynamo.py", line 130, in __call__
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]     compiled_gm = compiler_fn(gm, example_inputs)
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/__init__.py", line 2340, in __call__
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]     return compile_fx(model_, inputs_, config_patches=self.config)
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 1863, in compile_fx
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]     return aot_autograd(
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/backends/common.py", line 83, in __call__
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 1155, in aot_module_simplified
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]     compiled_fn = dispatch_and_compile()
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 1131, in dispatch_and_compile
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]     compiled_fn, _ = create_aot_dispatcher_function(
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 580, in create_aot_dispatcher_function
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]     return _create_aot_dispatcher_function(
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 830, in _create_aot_dispatcher_function
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]     compiled_fn, fw_metadata = compiler_fn(
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]                                ^^^^^^^^^^^^
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/_aot_autograd/jit_compile_runtime_wrappers.py", line 678, in aot_dispatch_autograd
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]     compiled_fw_func = aot_config.fw_compiler(fw_module, adjusted_flat_args)
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 489, in __call__
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]     return self.compiler_fn(gm, example_inputs)
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 1741, in fw_compiler_base
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]     return inner_compile(
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 569, in compile_fx_inner
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]     return wrap_compiler_debug(_compile_fx_inner, compiler_name="inductor")(
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/repro/after_aot.py", line 102, in debug_wrapper
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W0821 07:59:23.348000 233 torch/_dynamo/convert_frame.py:1233]                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]     compiled_fn = self.call_user_compiler(gm)
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/output_graph.py", line 1432, in call_user_compiler
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]     return self._call_user_compiler(gm)
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/output_graph.py", line 1483, in _call_user_compiler
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]     raise BackendCompilerFailed(self.compiler_fn, e).with_traceback(
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/output_graph.py", line 1462, in _call_user_compiler
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/repro/after_dynamo.py", line 130, in __call__
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]     compiled_gm = compiler_fn(gm, example_inputs)
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/__init__.py", line 2340, in __call__
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]     return compile_fx(model_, inputs_, config_patches=self.config)
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 1863, in compile_fx
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]     return aot_autograd(
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/backends/common.py", line 83, in __call__
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 1155, in aot_module_simplified
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]     compiled_fn = dispatch_and_compile()
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 1131, in dispatch_and_compile
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]     compiled_fn, _ = create_aot_dispatcher_function(
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 580, in create_aot_dispatcher_function
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]     return _create_aot_dispatcher_function(
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 830, in _create_aot_dispatcher_function
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]     compiled_fn, fw_metadata = compiler_fn(
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]                                ^^^^^^^^^^^^
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/_aot_autograd/jit_compile_runtime_wrappers.py", line 678, in aot_dispatch_autograd
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]     compiled_fw_func = aot_config.fw_compiler(fw_module, adjusted_flat_args)
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_functorch/aot_autograd.py", line 489, in __call__
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]     return self.compiler_fn(gm, example_inputs)
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 1741, in fw_compiler_base
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]     return inner_compile(
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 569, in compile_fx_inner
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]     return wrap_compiler_debug(_compile_fx_inner, compiler_name="inductor")(
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/repro/after_aot.py", line 102, in debug_wrapper
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 685, in _compile_fx_inner
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]     mb_compiled_graph = fx_codegen_and_compile(
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]                         ^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 1129, in fx_codegen_and_compile
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]     return scheme.codegen_and_compile(gm, example_inputs, inputs_to_check, graph_kwargs)
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py", line 1044, in codegen_and_compile
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]     compiled_fn = graph.compile_to_module().call
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/graph.py", line 2027, in compile_to_module
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]     return self._compile_to_module()
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/graph.py", line 2033, in _compile_to_module
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]                                                              ^^^^^^^^^^^^^^
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/graph.py", line 1964, in codegen
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]     self.scheduler = Scheduler(self.operations)
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 1798, in __init__
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]     self._init(nodes)
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 1816, in _init
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 1816, in <listcomp>
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 1947, in create_scheduler_node
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]     return SchedulerNode(self, node)
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 893, in __init__
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]     self._compute_attrs()
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 907, in _compute_attrs
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]     group_fn = self.scheduler.get_backend(device).group_fn
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 3441, in get_backend
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]     self.backends[device] = self.create_backend(device)
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]   File "/usr/local/lib/python3.11/dist-packages/torch/_inductor/scheduler.py", line 3428, in create_backend
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]     raise RuntimeError(
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233] RuntimeError: Found Tesla P100-PCIE-16GB which is too old to be supported by the triton GPU compiler, which is used as the backend. Triton only supports devices of CUDA Capability >= 7.0, but your device is of CUDA capability 6.0
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W0821 07:59:24.163000 233 torch/_dynamo/convert_frame.py:1233]
# Epoch 1/20: 100%|██████████| 2105/2105 [18:00<00:00,  1.95it/s, train_loss=0.3250]
# >>> E01 | train_loss=0.3249 | val_loss=0.1747 | val_acc=0.9392 | val_f1=0.9393
# Saved best model to: /kaggle/working/modernbert_sst2_best.pt (acc=0.9392)
# Epoch 2/20: 100%|██████████| 2105/2105 [17:59<00:00,  1.95it/s, train_loss=0.1489]
# >>> E02 | train_loss=0.1491 | val_loss=0.1517 | val_acc=0.9472 | val_f1=0.9480
# Saved best model to: /kaggle/working/modernbert_sst2_best.pt (acc=0.9472)
# Epoch 3/20: 100%|██████████| 2105/2105 [18:00<00:00,  1.95it/s, train_loss=0.0920]
# >>> E03 | train_loss=0.0921 | val_loss=0.1903 | val_acc=0.9450 | val_f1=0.9471
# Epoch 4/20: 100%|██████████| 2105/2105 [18:01<00:00,  1.95it/s, train_loss=0.0593]
# >>> E04 | train_loss=0.0594 | val_loss=0.1990 | val_acc=0.9438 | val_f1=0.9446
# Epoch 5/20: 100%|██████████| 2105/2105 [18:01<00:00,  1.95it/s, train_loss=0.0411]
# >>> E05 | train_loss=0.0410 | val_loss=0.2561 | val_acc=0.9404 | val_f1=0.9408
# Epoch 6/20: 100%|██████████| 2105/2105 [18:01<00:00,  1.95it/s, train_loss=0.0290]
# >>> E06 | train_loss=0.0290 | val_loss=0.3453 | val_acc=0.9381 | val_f1=0.9405
# Epoch 7/20: 100%|██████████| 2105/2105 [18:01<00:00,  1.95it/s, train_loss=0.0208]
# >>> E07 | train_loss=0.0208 | val_loss=0.3152 | val_acc=0.9438 | val_f1=0.9454
# Epoch 8/20: 100%|██████████| 2105/2105 [18:01<00:00,  1.95it/s, train_loss=0.0164]
# >>> E08 | train_loss=0.0164 | val_loss=0.3690 | val_acc=0.9346 | val_f1=0.9360
# Epoch 9/20: 100%|██████████| 2105/2105 [18:01<00:00,  1.95it/s, train_loss=0.0137]
# >>> E09 | train_loss=0.0137 | val_loss=0.4314 | val_acc=0.9312 | val_f1=0.9332
# Epoch 10/20: 100%|██████████| 2105/2105 [18:01<00:00,  1.95it/s, train_loss=0.0102]
# >>> E10 | train_loss=0.0102 | val_loss=0.5221 | val_acc=0.9140 | val_f1=0.9193
# Epoch 11/20: 100%|██████████| 2105/2105 [18:01<00:00,  1.95it/s, train_loss=0.0087]
# >>> E11 | train_loss=0.0087 | val_loss=0.4603 | val_acc=0.9369 | val_f1=0.9387
# Epoch 12/20: 100%|██████████| 2105/2105 [18:01<00:00,  1.95it/s, train_loss=0.0053]
# >>> E12 | train_loss=0.0052 | val_loss=0.4713 | val_acc=0.9312 | val_f1=0.9336
# Epoch 13/20: 100%|██████████| 2105/2105 [18:00<00:00,  1.95it/s, train_loss=0.0031]
# >>> E13 | train_loss=0.0031 | val_loss=0.4649 | val_acc=0.9392 | val_f1=0.9405
# Epoch 14/20: 100%|██████████| 2105/2105 [18:00<00:00,  1.95it/s, train_loss=0.0028]
# >>> E14 | train_loss=0.0028 | val_loss=0.5190 | val_acc=0.9358 | val_f1=0.9385
# Epoch 15/20: 100%|██████████| 2105/2105 [18:00<00:00,  1.95it/s, train_loss=0.0024]
# >>> E15 | train_loss=0.0024 | val_loss=0.5431 | val_acc=0.9335 | val_f1=0.9348
# Epoch 16/20: 100%|██████████| 2105/2105 [18:00<00:00,  1.95it/s, train_loss=0.0013]
# >>> E16 | train_loss=0.0014 | val_loss=0.5637 | val_acc=0.9358 | val_f1=0.9371
# Epoch 17/20: 100%|██████████| 2105/2105 [18:00<00:00,  1.95it/s, train_loss=0.0009]
# >>> E17 | train_loss=0.0009 | val_loss=0.6316 | val_acc=0.9335 | val_f1=0.9357
# Epoch 18/20: 100%|██████████| 2105/2105 [18:01<00:00,  1.95it/s, train_loss=0.0002]
# >>> E18 | train_loss=0.0002 | val_loss=0.6871 | val_acc=0.9369 | val_f1=0.9392
# Epoch 19/20: 100%|██████████| 2105/2105 [18:01<00:00,  1.95it/s, train_loss=0.0001]
# >>> E19 | train_loss=0.0001 | val_loss=0.7078 | val_acc=0.9358 | val_f1=0.9381
# Epoch 20/20: 100%|██████████| 2105/2105 [18:01<00:00,  1.95it/s, train_loss=0.0001]
# >>> E20 | train_loss=0.0001 | val_loss=0.7139 | val_acc=0.9346 | val_f1=0.9369

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(history["train_loss"], label="train_loss")
plt.plot(history["val_loss"], label="val_loss")
plt.xlabel("epoch"); plt.ylabel("loss"); plt.legend(); plt.title("Loss")
plt.show()

plt.figure()
plt.plot(history["val_acc"], label="val_acc")
plt.plot(history["val_f1"], label="val_f1")
plt.xlabel("epoch"); plt.ylabel("score"); plt.legend(); plt.title("Validation metrics")
plt.show()

# %%
model.eval()
sample_texts = [
    "This movie was absolutely wonderful!",
    "The script was boring and the acting was terrible."
]
enc = tokenizer(sample_texts, return_tensors="pt", padding=True, truncation=True, max_length=MAX_LEN).to(device)
with torch.no_grad():
    logits, _ = model(enc["input_ids"], enc["attention_mask"])
preds = torch.argmax(logits, dim=-1).cpu().tolist()
for t, p in zip(sample_texts, preds):
    print(f"{t} -> {'Positive' if p==1 else 'Negative'}")
# Out:
# This movie was absolutely wonderful! -> Positive
# The script was boring and the acting was terrible. -> Negative

# %%
# Load lại best checkpoint
ckpt_path = "/kaggle/working/modernbert_sst2_best.pt" if "KAGGLE_URL_BASE" in os.environ else "/content/modernbert_sst2_best.pt"
ckpt = torch.load(ckpt_path, map_location=device)
model = ModernBERTClassifier(ckpt["model_name"], num_labels=2).to(device)
model.load_state_dict(ckpt["model_state_dict"])
tokenizer = AutoTokenizer.from_pretrained(ckpt["tokenizer"])
print("Best val_acc:", ckpt["val_acc"])
# Out:
# Best val_acc: 0.9472477064220184
